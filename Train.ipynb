# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('alldata.csv')

#select training vs test data
df['is_train'] = np.random.uniform(0, 1, len(df)) <= .80
train, test = df[df['is_train']==True], df[df['is_train']==False]

print('Number of quotes in the training data:', len(train))
print('Number of quotes in the test data:',len(test))

features = df.columns[:4]
features

df
#y = pd.factorize(train['Boolean'])[0]


#clf = RandomForestClassifier(n_jobs=2, random_state=0)
#clf.fit(train[features], y)
# Out:
# Number of quotes in the training data: 2
# Number of quotes in the test data: 0
#                                                    0  \
# 0                                                 no
# 1    imagination and logic  Oh  it was to be so j...
#
#                                                    1  \
# 0                                                 no
# 1    imagination and logic  Oh  it was to be so j...
#
#                                                    2  \
# 0                                                 no
# 1    imagination and logic  Oh  it was to be so j...
#
#                                                    3  \
# 0                                                 no
# 1    imagination and logic  Oh  it was to be so j...
#
#                                                    4  \
# 0                                                 no
# 1    imagination and logic  Oh  it was to be so j...
#
#                                                    5  \
# 0                                                 no
# 1    imagination and logic  Oh  it was to be so j...
#
#                                                    6  \
# 0                                                 no
# 1    imagination and logic  Oh  it was to be so j...
#
#                                                    7  \
# 0                                                 no
# 1    imagination and logic  Oh  it was to be so j...
#
#                                                    8  \
# 0                                                 no
# 1    imagination and logic  Oh  it was to be so j...
#
#                                                    9   ...     \
# 0                                                 no   ...
# 1    imagination and logic  Oh  it was to be so j...   ...
#
#                                                16395  \
# 0                                                yes
# 1    imagination and logic  Oh  it was to be so j...
#
#                                                16396  \
# 0                                                yes
# 1    imagination and logic  Oh  it was to be so j...
#
#                                                16397  \
# 0                                                yes
# 1    imagination and logic  Oh  it was to be so j...
#
#                                                16398  \
# 0                                                yes
# 1    imagination and logic  Oh  it was to be so j...
#
#                                                16399  \
# 0                                                yes
# 1    imagination and logic  Oh  it was to be so j...
#
#                                                16400  \
# 0                                                yes
# 1    imagination and logic  Oh  it was to be so j...
#
#                                                16401  \
# 0                                                yes
# 1    imagination and logic  Oh  it was to be so j...
#
#                                                16402  \
# 0                                                yes
# 1    imagination and logic  Oh  it was to be so j...
#
#                                                16403 is_train
# 0                                                yes     True
# 1    imagination and logic  Oh  it was to be so j...     True
#
# [2 rows x 16405 columns]
