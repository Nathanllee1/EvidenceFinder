# %% [markdown]
# # Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# # Open Page

# %%
page = requests.get("https://www.litcharts.com/")
books = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# # Absolute Mess

# %%
quotelist = []
themes = []
book_link = []

quotetheme = {}

#Find books
for book in books.find_all(class_='book hoverable', href=True):
    
    #make into a real url
    book_url = 'https://www.litcharts.com' + book['href'] + '/quotes'
    book_link.append(book_url)
    print('Found: ' + book_url)
    
    #Open quotepage
    for links in book_link:
        quote_page_request = requests.get(str(links))
        quote_page = BeautifulSoup(quote_page_request.content, 'html.parser')
        
        #Find quotes
        for quotes in quote_page.find_all(class_='quote-text'):
            quote = str(quotes.get_text())
            print('Quote: ' + quote)
            quotelist.append(quote)
            
            #Find themes for those quotes
        for theme in quote_page.find_all(class_ ='inline-popup-trigger'):
            themelist = []
            themelist.append(theme.get_text())
            print('Themes: ' + str(themelist))
        
        quotetheme.update({quote : themelist})
# Out:
# Found: https://www.litcharts.com/lit/12-years-a-slave/quotes
# Quote: Thus far the history of my life presents nothing whatever unusual—nothing but the common hopes, and loves, and labors of an obscure colored man, making his humble progress in the world […] Now I had approached within the shadow of the cloud, into the thick darkness whereof I was soon to disappear, thenceforward to be hidden from the eyes of all my kindred, and shut out from the sweet light of liberty, for many a weary year.
# Quote: The idea struck me as a prudent one, though I think it would scarcely have occurred to me, had they not proposed it […] I must confess, that the papers were scarcely worth the cost of obtaining them—the apprehension of danger to my personal safety never having suggested itself to me in the remotest manner.
# ...

# %%
dataframe = pd.DataFrame.from_dict(quotetheme)
df.to_csv(quotes.csv, encoding='utf-8', index=False)
dataframe

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2185e7f0d32f> in <module>
# ----> 1 for theme in quote_page.find_all(class_='theme inline-popup-trigger'):
#       2                 themelist = []
#       3                 themelist.append(theme.get_text())
#       4                 print('Themes: ' + str(themelist))
#
# NameError: name 'quote_page' is not defined
